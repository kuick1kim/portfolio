# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1cboHrESmwxe6XMX-ekFJys_mtoanoWTZ#scrollTo=86557235"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %%
# !wget "source_of_your_target_file"
# !unzip "your_file_name.zip"
# !rm ~/.cache/matplotlib -rf
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.font_manager as fm
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
# Out:
# sys_font number: 70
# nanum_font number: 31

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

# fetch the name of font that was installed
path = 'https://github.com/kuick1kim/01colap/blob/main/NanumBarunGothic.ttf'
fontprop = fm.FontProperties(fname=path)

# %%
# %matplotlib inline  

# import matplotlib as mpl  # 기본 설정 만지는 용도
# import matplotlib.pyplot as plt  # 그래프 그리는 용도
# import matplotlib.font_manager as fm  # 폰트 관련 용도

# %%
# !apt install fonts-nanum
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# Out:
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 4 dirs
# /usr/share/fonts/truetype/dejavu: caching, new cache contents: 22 fonts, 0 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 31 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# !rm ~/.cache/matplotlib -rf
#visualization
import matplotlib as plt
import matplotlib.pylab as plb
# import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sns

import matplotlib.font_manager as fm
import numpy as np
import pandas as pd

# 브라우저에서 바로 그려지도록 
# %matplotlib inline

# 그래프에 retina display 적용
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic') 

# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)

# import matplotlib.pyplot as plt

import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 판다스 표를 모두 보는 옵션
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)
# 브라우저에서 바로 그려지도록 

# 유니코드에서  음수 부호설정
pd.options.plotting.matplotlib.register_converters = True
# fm._rebuild()
# 그래프를 한번 보려함

# %%
# 데이터를 가져옴
# 1번 데이터를 열어보는셀

# 엑셀로 데이터가 저장되어있고 그것을 여는 방법 
# 바탕화면에 big 폴더를 만들고 01 out 폴더를 만들어서 그 안에다 넣어둠
# 파일명이 A이다. 
df=pd.read_excel('https://github.com/kuick1kim/01colap/blob/main/%EC%99%B8%EC%8B%9D%EC%82%B0%EC%97%85%EA%B2%BD%EA%B8%B0%EC%A0%84%EB%A7%9D%EC%A7%80%EC%88%98_10%EC%B0%A8%EA%B0%9C%EC%A0%95_5%EC%A0%90%EC%B2%99%EB%8F%84__20211101132309.xlsx?raw=true')

# 인덱스 삭제해줌 열과 행을 바꾸려니까 인덱스가 필요없음을 느낌
df=df.set_index('외식업종별')
# 행과 열을 변환함
df=df.transpose()
df[:3]
# Out:
# 외식업종별     전체소계   한식소계  한식 일반 음식점업  한식 면요리 전문점  한식 육류요리 전문점  한식 해산물요리 전문점  \
# 2018.25  74.81  73.02       74.10       79.55        69.42         71.26
# 2018.50  73.94  72.13       72.45       78.33        70.96         69.29
# 2018.75  72.60  70.20       70.52       81.34        69.79         63.04
#
# 외식업종별    외국 전체 소계  중식 음식점업  일식 음식점업  서양식 음식점업  기타 외국식 음식점업  구내식당업 소계  출장음식 소계  \
# 2018.25     80.08    73.45    79.91     82.93        96.93     82.80    69.89
# 2018.50     75.49    73.96    75.45     78.80        75.50     84.68    72.73
# 2018.75     74.35    73.10    71.13     79.61        75.64     80.07    71.74
#
# 외식업종별    간이음식점 소계   제과점업  피자 햄버거 샌드위치 및 유사 음식점업  치킨 전문점  김밥 및 기타 간이 음식점업  \
# 2018.25     76.17  81.25                  80.22   73.58            72.54
# 2018.50     77.19  77.95                  78.94   79.90            73.24
# 2018.75     76.09  80.32                  83.84   70.79            74.90
#
# ...

# %%
plt.rc('font', family='NanumBarunGothic') 
a= df['전체소계']
b= df['한식소계']
c= df['외국 전체 소계']
jung = df['중식 음식점업']
il = df['일식 음식점업']

import matplotlib.pyplot as plt
plt.figure(figsize=(13,5))
plt.plot(a, 'r-')
plt.plot(b)
plt.plot(c)
plt.plot(jung)
plt.plot(il)
plt.legend(['전체','한식','외국' ])
plt.show()

# %%
#너무 복잡해서 잘 보기가 어려움
a=df['전체소계']
b=df['한식소계']
c=df['외국 전체 소계']
d=df['구내식당업 소계']
e=df['출장음식 소계']
f=df['간이음식점 소계']
g=df['주점 소계']
h=df['비알콜 음료소계']

plt.rc('font', family='NanumBarunGothic') 
plt.figure(figsize=(18,15))

plt.subplot(421)
plt.plot(a, 'r-')
plt.title('전체소계')
plt.legend(['전체소계'])

plt.subplot(422)
plt.plot(a,'r-')
plt.plot(b)
plt.title('한식소계')
plt.legend(['전체소계','한식'])

plt.subplot(423)
plt.plot(a,'r-')
plt.plot(c)
plt.title('외국 전체 소계')
plt.legend(['전체소계','외국식'])

plt.subplot(424)
plt.plot(a,'r-')
plt.plot(d)
plt.title('구내식당업성장율')
plt.legend(['전체소계','구내식당'])

plt.subplot(425)
plt.plot(a,'r-')
plt.plot(e)
plt.title('출장음식 소계')
plt.legend(['전체소계','출장음식'])

plt.subplot(426)
plt.plot(a,'r-')
plt.plot(f)
plt.title('간이음식점 소계')
plt.legend(['전체소계','간이음식'])

plt.subplot(427)
plt.plot(a,'r-')
plt.plot(g)
plt.title('주점 소계')
plt.legend(['전체소계','주점'])

plt.subplot(428)
plt.plot(a,'r-')
plt.plot(h)
plt.title('비알콜 음료소계')
plt.legend(['전체소계','비알콜'])

plt.show()

# %%
# 외식업은 2018년에 비해 전반적으로 성장율이 둔화되고 있으며
# 한식은 더욱 둔화되고 있다. 
# 외국식은 업계에 비해 전반적으로 성장율이 좋은 편이며
# 구내식당의 성장율을 폭발적이다. 
# 출장음식은 전반적을로 하락하였으나 최근 성장하는 추세이며
# 간이음식점은 시장에 성장이 높은 편이다. 
# 주점은 크게 하락하고 있으며
# 비알콜점포는 전체시장에비하여 성장하는 편이다.

# %%
df1=df[:]

# %%
d=df1['구내식당업 소계']
e=df1['출장음식 소계']
f=df1['간이음식점 소계']
g=df1['주점 소계']
h=df1['비알콜 음료소계']

plt.figure(figsize=(18,12))
# 외국식을 알아보고자 합니다. 

a= df1['간이음식점 소계']
b= df1['제과점업']
c= df1['피자 햄버거 샌드위치 및 유사 음식점업']
d= df1['치킨 전문점']
e= df1['김밥 및 기타 간이 음식점업']
f= df1['간이 음식 포장 판매 전문점']

plt.title('간이음식점 소계')
plt.title('제과점업')
plt.title('피자 햄버거 샌드위치 및 유사 음식점업')
plt.title('치킨 전문점')
plt.title('김밥 및 기타 간이 음식점업')
plt.title('간이 음식 포장 판매 전문점')

plt.subplot(321)
plt.plot(a, 'r-')
plt.title('간이음식점 소계')
plt.legend(['간이음식점'])

plt.subplot(322)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('제과점업')
plt.legend(['간이음식점','제과점'])
           
plt.subplot(323)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('피자 햄버거 샌드위치 및 유사 음식점업')
plt.legend(['간이음식점','피자 햄버거 유사음식'])

plt.subplot(324)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('치킨 전문점')
plt.legend(['간이음식점','치킨 전문점'])

plt.subplot(325)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('김밥 및 기타 간이 음식점업')
plt.legend(['간이음식점','김밥 및 기타 간이 음식'])

plt.subplot(326)
plt.plot(a, 'r-')
plt.plot(f)
plt.title('간이 음식 포장 판매 전문점')
plt.legend(['간이음식점','포장판매 전문'])

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### - 간이 음식점에서 제과점은 크게 상승하였다.
# ### - 피자 샌드위치 햄버거의 성장이 뚜렸했다
# ### - 치킨 전문점은 집입이 용의하지 않았다
# ### - 김밥도 진입이 용이하지 않았으며
# ### - 포장 판매 전문점도 점포수가 평균에 비해 늘지는 않았다

# %%
plt.figure(figsize=(18,6))
plt.plot(a, 'r-')
plt.plot(d)
plt.title('치킨 전문점')
plt.legend(['간이음식점','치킨 전문점'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# 국세청의 임대여부 데이터

# %%
# 1번 데이터를 열어보는셀
#새로운것을 불러냄
df = pd.read_excel('https://github.com/kuick1kim/01colap/blob/main/%EC%82%AC%EC%97%85%EC%9E%A5_%EC%9E%84%EC%B0%A8%ED%98%84%ED%99%A9_20211101121836.xlsx?raw=true', sheet_name='a')
df

# 국세청 외식산업 경기전망지수
# Out:
#          특성별(2)                 특성별(3)                 특성별(4)      2018  \
# 0        특성별(2)                 특성별(3)                 특성별(4)  임차여부 (%)
# 1        특성별(2)                 특성별(3)                 특성별(4)         예
# 2            소계                     전체                     소계      85.5
# 3         일반음식점                 일반음식전체                     소계      79.9
# 4         일반음식점                     한식                     소계      78.8
# 5         일반음식점                     중식                     소계      78.6
# 6         일반음식점                     일식                     소계      96.6
# 7         일반음식점                    서양식                     소계      93.7
# 8         일반음식점                 기타 외국식                     소계      94.9
# 9       일반음식점 외              일반음식점외 전체                     소계      91.6
# 10      일반음식점 외               기관 구내식당업                     소계      59.1
# 11      일반음식점 외              출장·이동음식점업                     소계      73.6
# ...

# %%
# 1번 임차 여부 알아보기 나머지 비율은 자가비율이다.
# 데이터를 쪼개오기
df1 = df.iloc[2:9,[1,3,5,7]]
df1=df1.set_index('특성별(3)')
df1=df1.transpose()
df1
# Out:
# 특성별(3)    전체 일반음식전체    한식    중식    일식   서양식 기타 외국식
# 2018    85.5   79.9  78.8  78.6  96.6  93.7   94.9
# 2019    89.9   87.9  88.2  78.4    91  93.9   94.4
# 2020    85.6   80.8  79.9    78  93.1  91.1   88.4

# %%
# 그래프로 최근 3년간  임대한 임대비율 알아보기

plt.figure(figsize=(15,15))

a= df1['전체']
b= df1['일반음식전체']
c= df1['한식']
d= df1['중식']
e= df1['일식']
f= df1['서양식']
g= df1['기타 외국식']

plt.title('전체 임차비율')
plt.title('일반음식전체 임차비율')
plt.title('한식 임차비율')
plt.title('중식 임차비율')
plt.title('일식 임차비율')
plt.title('서양식 임차비율')
plt.title('기타 외국식 임차비율')

plt.subplot(321)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('일반음식전체 임차비율')
plt.legend(['전체','일반음식점'])

plt.subplot(322)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('한식 임차비율')
plt.legend(['전체','한식 임차비율'])

plt.subplot(323)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('중식 임차비율')
plt.legend(['전체','중식 임차비율'])

plt.subplot(324)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('일식 임차비율')
plt.legend(['전체','일식 임차비율'])

plt.subplot(325)
plt.plot(a, 'r-')
plt.plot(f)
plt.title('서양식 임차비율')
plt.legend(['전체','서양식 임차비율'])

plt.subplot(326)
plt.plot(a, 'r-')
plt.plot(g)
plt.title('기타 외국식 임차비율')
plt.legend(['전체','기타 외국식 임차비율'])

plt.show()

# %%
# 일반음식점과 일반음식점이 아닌 종류로 분류된다. 
# 일반음식점은 자기 건물이 아니라 임차해서 보통 비지니스를한다
# 1. 한식과 일반음식은 2019년 임대를 많이 하고 그 이후에 평균비율에 비해
# 자가를 통해서 운영하는 경우가 많은것 같다. 
# 2. 중식은 일반 음식점에 비해 월세를 내고 하는 비율이 적은 편이다. 운영이 훨씬 안정적이라고 
# 볼수 있다. 
# 3. 일식은 2018년에 개업을 많이 한 것으로 보이며, 2020년 이후에도 개업을 많이 한 것으로 보인다
# 대부분 일식은 90%이상이 월세를 내고 운영하는 편이다. 

# 4. 서양식도 일식과 마찬가지로 임대하여 사용하는 비율이 높고 2018년에는 개업을 많이 하였으나
# 성장율이 높지는 않은 것으로 보인다. 
# 5. 기타외국식은 현 데이터에서 분류가 나와있지는 않으나. 임대에서 점차 자가로 가는 것이 보인다.

# %%
# 일반음식점외에 어떤 비율인지 알아보고 싶다. 
# df[:10]
df2 = df.iloc[9:18,[1,3,5,7]]
df2=df2.set_index('특성별(3)')

# 뒤집기
df2=df2.transpose()
df2
# Out:
# 특성별(3) 일반음식점외 전체 기관 구내식당업 출장·이동음식점업   제과점 피자·햄버거·샌드위치 및 유사 음식점업 치킨전문점  \
# 2018        91.6     59.1      73.6  92.6                  94.3    92
# 2019          92       70      75.9  93.7                  95.9  94.4
# 2020        90.9     59.2      78.2  92.2                  94.6  89.3
#
# 특성별(3) 김밥 및 기타 간이 음식점업 간이 음식 포장 판매 전문점   주점업
# 2018              88.1            79.2  95.9
# 2019              89.2            91.4  93.9
# 2020              90.2            85.9  94.6

# %%
plt.figure(figsize=(15,15))
# 일반음식점이 아닌곳은 임대 비율이 어떤가?

a= df2['일반음식점외 전체']
b= df2['기관 구내식당업']
c= df2['출장·이동음식점업']
d= df2['제과점']
e= df2['피자·햄버거·샌드위치 및 유사 음식점업']
f= df2['치킨전문점']
g= df2['김밥 및 기타 간이 음식점업']
h= df2['간이 음식 포장 판매 전문점']
i= df2['주점업']

plt.title('일반음식점외 전체')
plt.title('기관 구내식당업')
plt.title('출장·이동음식점업')
plt.title('제과점')
plt.title('피자·햄버거·샌드위치 및 유사 음식점업')
plt.title('치킨전문점')
plt.title('김밥 및 기타 간이 음식점업')
plt.title('간이 음식 포장 판매 전문점')
plt.title('주점업')

plt.subplot(421)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('기관 구내식당업')
plt.legend(['일반음식점외','기관 구내식당업'])

plt.subplot(422)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('출장·이동음식점업')
plt.legend(['일반음식점외','출장/이동'])


plt.subplot(423)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('제과점')
plt.legend(['일반음식점외','제과점'])


plt.subplot(424)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('피자·햄버거·샌드위치')
plt.legend(['일반음식점외','피자 햄버거'])


plt.subplot(425)
plt.plot(a, 'r-')
plt.plot(f)
plt.title('치킨전문점')
plt.legend(['일반음식점외','치킨 전문점'])


plt.subplot(426)
plt.plot(a, 'r-')
plt.plot(g)
plt.title('김밥 및 간이 음식점업')
plt.legend(['일반음식점외','김밥 간이음식'])


plt.subplot(427)
plt.plot(a, 'r-')
plt.plot(h)
plt.title('음식 포장 판매 전문점')
plt.legend(['일반음식점외','포장판매'])


plt.subplot(428)
plt.plot(a, 'r-')
plt.plot(i)
plt.title('주점업')
plt.legend(['일반음식점외','주점'])

plt.show()

# %%
# # 이번에는 일반음식점이 아닌 기타 음식을 다루는 업종은 어떤지 알아보고자 하였다. 
# 기관구내 식당업은 굉장히 특이한 자료를 보여주었다. 60프로정도가 임대를 하였고
# 나머지 40%가량의 자가였다. 공장이나 기관내에 식당업을 하여 직원들의 식사를 공급하는 
# 비율이 많은 것으로 보인다. 이 자료는 위의 자료를 보며 성장율을 확인해보는것이 좋겠다고 생각한다. 

# 2. 출장이동 음식점도 자가가 많은 편이며, 점차 임대비율이 상승하는 것으로 보인다. 
# 3. 제과점은 임대비율이 높으며, 2019년에 많은 사람들이 개업을 한것으로 보인다. 
# 4. 피자 햄버거 샌드위치는 대부분 임대를 통해 수익을 낸다. 
# 고수익이 가능한 점포는 임대를 하는것이 좋은것 같다. 
# 5. 치킨 전문점은 임대를 많이 하였으나. 2020년 이후에 자가확율이 높아진것을 볼 수 있다. 
# 돈을 벌어서 산것인지, 임대업자가 폐업을 한것인지는 확인할 수는 없다. 
# 6. 김밥 간이 음식점은 자가 비율이 약간 높은 편이나 점차 성장해 나가는 것 같다. 
# 7. 음식포장 판매전문점은 2019년에 빠르게 성장했으나. 2020년에 성장이 줄어든것 같다
# 8. 주점업은 임대비율이 높은 편이다. 주점은 자가로 하는 비율이 높지 않은것으로 보인다.

# %%
plt.figure(figsize=(15,3))
plt.plot(a, 'r-')
plt.plot(f)
plt.title('치킨전문점')
plt.legend(['일반음식점외','치킨 전문점'])
plt.show()

# %%
# 1번 데이터를 열어보는셀

dfb = pd.read_excel('https://github.com/kuick1kim/01colap/blob/main/%EC%82%AC%EC%97%85%EC%9E%A5_%EC%9E%84%EC%B0%A8%ED%98%84%ED%99%A9_20211101121836.xlsx?raw=true', sheet_name='b')
dfb

# 투자금액별로 자가비율이 높은지 낮은지 알아 보고자 한다. /
# 1번 임차 여부 알아보기
# 데이터를 쪼개오기
dfb1 = dfb.iloc[:,:]
dfb1


# 국세청 외식산업 경기전망지수
# Out:
#     특성별(1)       특성별(2)                 특성별(3)                 특성별(4)  \
# 0   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 1   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 2       전체           소계                     전체                     소계
# 3      업종별        일반음식점                일반음식점전체                     소계
# 4      업종별        일반음식점                     한식                     소계
# 5      업종별        일반음식점                     중식                     소계
# 6      업종별        일반음식점                     일식                     소계
# 7      업종별        일반음식점                    서양식                     소계
# 8      업종별        일반음식점                 기타 외국식                     소계
# 9      업종별      일반음식점 외              일반음식점외 소계                     소계
# 10     업종별      일반음식점 외               기관 구내식당업                     소계
# 11     업종별      일반음식점 외              출장·이동음식점업                     소계
# ...

# %%
import matplotlib.pyplot as plt

kk18= dfb1.iloc[2:3,4:10]
# 세로로 바꿔줌
# 뒤집기
kk18=kk18.transpose()
kk18=kk18[2]
kk18

kk19= dfb1.iloc[2:3,11:17]
# 세로로 바꿔줌
# 뒤집기
kk19=kk19.transpose()
kk19=kk19[2]
kk19

kk20= dfb1.iloc[2:3,18:24]
# 세로로 바꿔줌
# 뒤집기
kk20=kk20.transpose()
kk20=kk20[2]
kk20


list = [kk18, kk19, kk20]
title = ['2018', '2019', '2020']

for i ,t in zip(list,title):
    t= t+' 년도 전체 퍼센트'
    plt.figure(figsize=(5,5))
    title_font = {    'fontsize': 26, 'fontweight': 'bold'}
    plt.title(t,fontdict=title_font)
    
    
    labels = ['1천 미만','2천 미만','5천 미만','1억 미만','1억 이상','무응답' ]

    plt.pie(i, labels=labels,autopct='%.1f%%',startangle=90)
    plt.show()

# %%
# 2 = 일반음식점전체  ，3 = 한식    ，4 = 중식    ，5 = 일식    ，
# 6 = 서양식  ，7 = 기타 외국식 ，8 = 일반음식점외 소계   ，9 = 기관 구내식당업 ，
# 10 = 출장·이동음식점업   ，11 = 제과점  ，
# 12 = 피자·햄버거·샌드위치 및 유사 음식점업   ，13 = 치킨전문점  ，
# 14 = 김밥 및 기타 간이 음식점업  ，15 = 간이 음식 포장 판매 전문점  ，16 = 주점업  ，
# 17 = 비알콜 음료점업 ，


# 18 = 프랜차이즈  ，19 = 비프랜차이즈    ，

# 20 = 서울권  ，
# 21 = 수도권  ，22 = 충청권  ，23 = 호남권  ，24 = 경남권  ，25 = 경북권  ，
# 26 = 5천만원 미만    ，27 = 5천만원~1억원 미만  ，28 = 1억원~5억원 미만    ，
# 29 = 5억원 이상

# %%
# 작업하다보니 할만한 방법이 생김
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic') 
a= 13

name = dfb.iloc[a+1,2]
# print(name)

kk18= dfb.iloc[a+1:a+2,4:10]
kk18=kk18.transpose()
kk18=kk18[a+1]

kk19= dfb.iloc[a+1:a+2,11:17]
# 세로로 바꿔줌
# 뒤집기
kk19=kk19.transpose()
kk19=kk19[a+1]

kk20= dfb.iloc[a+1:a+2,18:24]
# 세로로 바꿔줌
# 뒤집기
kk20=kk20.transpose()
kk20=kk20[a+1]

list = [kk18, kk19, kk20]
title = ['2018', '2019', '2020']

for i ,t in zip(list,title):
    t= '{} 창업 금액'.format(name) + t+' 년도'
    
    plt.figure(figsize=(7,7))
    
    title_font = {'fontsize': 24, 'fontweight': 'bold'}
    plt.title(t,fontdict=title_font)
    plt.rc('font', family='NanumBarunGothic') 
    
    labels = ['1천 미만','2천 미만','5천 미만','1억 미만','1억 이상','무응답' ]

    plt.pie(i, labels=labels,autopct='%.1f%%',startangle=90)
    # plt.savefig('c:/123kms/png/{}.png'.format(t))
    
    plt.show()

# %% [markdown]
# ![이미지](http://www.dailygrid.net/news/photo/201706/54451_32446_3950.jpg)

# %% [markdown]
# ## 치킨 창업 어떻게 할것인가?

# %%
# 1번 데이터를 열어보는셀
# 업체별로 변환가능합니다.  하지만 틀이 동일해야 합니다. 

aa= 'https://raw.githubusercontent.com/kuick1kim/01colap/main/%EC%9A%94%EA%B8%B0%EC%9A%94-%EA%B6%8C%EC%84%A0%EB%8F%99-BBQ-%EC%88%98%EC%9B%90%EB%A7%A4%EC%82%B0%EC%84%B8%EB%A5%98%EC%A0%90.csv'
bb= 'https://raw.githubusercontent.com/kuick1kim/01colap/main/%EC%9A%94%EA%B8%B0%EC%9A%94-%EA%B6%8C%EC%84%A0%EB%8F%99-%EA%B5%90%EC%B4%8C%EC%B9%98%ED%82%A8-%EB%A7%A4%EA%B5%90%EC%A0%90.csv'
cc= 'https://raw.githubusercontent.com/kuick1kim/01colap/main/%EC%9A%94%EA%B8%B0%EC%9A%94-%EA%B6%8C%EC%84%A0%EB%8F%99-%EC%BD%94%EB%A6%AC%EC%97%94%ED%83%88%EA%B9%BB%EC%9E%8E%EB%91%90%EB%A7%88%EB%A6%AC%EC%B9%98%ED%82%A8-%EA%B6%8C%EC%84%A0%EC%A0%90.csv'
dd='https://raw.githubusercontent.com/kuick1kim/01colap/main/csv/%EC%9A%94%EA%B8%B0%EC%9A%94-%EC%84%9C%EC%B4%88%EB%8F%99-%ED%8E%98%EB%A6%AC%EC%B9%B4%EB%82%98-%EC%84%9C%EC%B4%88%EB%8F%99%EC%A0%90.csv' # 서초동 페리카나
ee = 'https://raw.githubusercontent.com/kuick1kim/01colap/main/csv/%EC%9A%94%EA%B8%B0%EC%9A%94-%EC%84%9C%EC%B4%88%EB%8F%99-%EC%BB%AC%ED%88%AC%EC%B9%98%ED%82%A8-%EC%84%9C%EC%B4%881%ED%98%B8%EC%A0%90.csv'#서초 컬투치킨
df = pd.read_csv(ee)
df[:10]
# Out:
#   크롤링시간   지역        가게이름    아이디  몇시간전  \
# 0  어제    서초동  컬투치킨-서초1호점  ba**님  어제
# 1  2일 전  서초동  컬투치킨-서초1호점  hy**님  2일 전
# 2  3일 전  서초동  컬투치킨-서초1호점  lk**님  3일 전
#
#                                                              주문내용  \
# 0  감자바사삭치킨＋케이준감자/1(맛 선택(매콤（매후라）),부위변경(뼈))
# 1  매후라치킨/1(치킨 종류 추가 선택(변경 안함))
# 2  화끈화닭치킨/1(치킨 종류 추가 선택(순살 변경),음료 추가 선택(음료 사이즈업（1.25 변경）)),새우튀김/1
#
#                                                        댓글  맛  양  배달  \
# 0  맛있었어요 또 주문할게요!!!                                        5  5  5
# 1  맛있엉ㅅㄹ~!~!~!~!                                           5  5  5
# 2  스트레스 풀려고 주문했어요~~화끈하고 넘 맛있네요 ~~치즈볼도 달콤쫀득~~새우튀김 맛도.좋구요~~  5  5  5
#
#                      사장  \
# 0  ----사장님 답글이 없어요 ----
# 1  ----사장님 답글이 없어요 ----
# 2  ----사장님 답글이 없어요 ----
#
#                                                                       사진주소
# 0  이미지는 없어요
# 1  이미지는 없어요
# 2  https://rev-static.yogiyo.co.kr/406ad409c0f68bed9133b70c39685a3a_tn.jpg

# %%
# 이업체 이용자가 찍은 사진
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import urllib.request

lk = df.iloc[1:10,11:12]
lk1= lk['사진주소']
lk1

def url_to_image(url):
  resp = urllib.request.urlopen(url)
  image = np.asarray(bytearray(resp.read()), dtype='uint8')
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)
  return image

for i in lk1:
  try:
    tiger_image = url_to_image(i)
    cv2_imshow(tiger_image)
  except:
    pass
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
lists = ['맛','양','배달']
# 맛으로 빈도 그래프보기
for list in lists:
  x= df[list]
  llll = list+" 점수빈도"
  title_font = {'fontsize': 24, 'fontweight': 'bold'}
  
  plt.figure(figsize=(5,4))
  plt.hist(x)
  plt.title(llll,fontdict=title_font)
  plt.show()

# %%
kk = len(df["몇시간전"].value_counts())
kk
# Out:
# 72

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') 
# 시간에 따른 빈도수
x= df['몇시간전']
plt.figure(figsize=(14,4))
plt.hist(x, bins=kk) #빈을 넣으니까. 갯수가 많아짐
# plt.hist(x)
title_font = {'fontsize': 24, 'fontweight': 'bold'}
plt.title("날짜 별 빈도 알아보기",fontdict=title_font)
plt.show()

# %%
df1=df[:]
df1[:1]
# df1로 새로운것으로 공부하기 하다가 지워지면 처음부터 불러와야 하기에
# 앞뒤 공백을 죽이려함
df1['주문내용']  = df1['주문내용'].str.strip()
df1['주문내용']
# 분할하는 방법
df1[['나누기1', '나누기2','나누기3','나누기4']] = df1['주문내용'].str.split(',', n=3, expand=True)
df3= df1['나누기1']
# df3 으로 새로운 데이터 프레임을 만들어서 한줄로 붙이기 
df3_2= df1['나누기2']
df3= pd.concat([df3, df3_2])
df3_X= df1['나누기3']
df3= pd.concat([df3, df3_X])
df3_X= df1['나누기4']
df3= pd.concat([df3, df3_X])
df3

# df3.isnull().sum()
# df3.notnull().sum()
#결측치 제거해주기
df3 = df3.dropna(axis=0)
# #인덱스 재정열
df3= df3.reset_index(drop=True)
aa = df3.value_counts()
aa1 = pd.DataFrame(aa)
aa1.head(20)

# 몇개인가 보기셀
# 데이타프레임으로 다시 만들기
# Out:
#                                   0
# 매후라치킨/1(치킨 종류 추가 선택(변경 안함))      67
# 마후라치킨/1(치킨 종류 추가 선택(변경 안함))      34
# 메후라반반치킨/1(치킨 종류 추가 선택(변경 안함))    24
# 간장마요치킨/1(치킨 종류 추가 선택(순살 변경))     22
# 음료 추가 선택(음료 사이즈업（1.25 변경）))      21
# 매후라치킨/1(치킨 종류 추가 선택(순살 변경))      18
# 마후라반반치킨/1(치킨 종류 추가 선택(변경 안함))    16
# 컬투치킨/1(치킨 종류 추가 선택(순살 변경))       13
# 마후라치킨/1(치킨 종류 추가 선택(순살 변경))      13
# 매후라양념치킨/1(치킨 종류 추가 선택(변경 안함))    13
# 컬투치킨/1(치킨 종류 추가 선택(변경 안함))       11
# 간장마요치킨/1(치킨 종류 추가 선택(변경 안함))     11
# 부위변경(뼈))                         10
# 마후라반반치킨/1(치킨 종류 추가 선택(순살 변경))    9
# 어니언크림새우치킨/1(치킨 종류 추가 선택(순살 변경))  9
# 추가 선택(치킨무 추가))                   8
# 매후라치킨/1(치킨 종류 추가 선택(변경 안함)       8
# 메후라반반치킨/1(치킨 종류 추가 선택(순살 변경))    8
# 마후라양념치킨/1(치킨 종류 추가 선택(순살 변경))    8
# 매후라양념치킨/1(치킨 종류 추가 선택(순살 변경))    8

# %%
aa1['내용']= aa1.index
aa1['내용1']= aa1[0]
aa1.head()
# 새롭게 복제해서 셀을 쓰려고 만듦 
#이부분은 더 나은 부분이 있을것임
ls= []
for i in aa1['내용']:
    a= i[:-2]
    ls.append(a)
ls
aa1['내용2'] = ls
del aa1['내용']

# 정열을 해주기
aa2 = aa1.sort_values(by=['내용2'], ascending=False)

import matplotlib.pyplot as plt
aa2 = aa1.sort_values(by=['내용1'], ascending=True)
aa2=aa2[-40:]
y= aa2['내용1']
x= aa2['내용2']
plt.rc('font', family='NanumBarunGothic') 
plt.figure(figsize=(5,10))
plt.rc('font', size=13)        # 기본 폰트 크기
plt.barh(x,y )

plt.show()

# %%
# !pip3 install konlpy
from konlpy.tag import *        #pip install konlpy 먼저 하세요
from matplotlib import font_manager , rc
from wordcloud import WordCloud  # pip install wordcloud 먼저 하세요
from collections import Counter

# %%
df1.head(1)
# 4점 이상의 리뷰는 긍정 리뷰, 3점 이하의 리뷰는 부정 리뷰로 평가합니다.
df1['y'] = df1['맛'].apply(lambda x: 1 if float(x) > 3 else 0)
print(df.shape)
# df1.head(1)

# 다른것으로 복사해서 분석 데이터가 망가질수 있어서 그렇게 하였음
df2=df1[:]

import re
# 한글 텍스트 만 뽑아내기
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거
def text_cleaning(text):
    # 한글의 정규표현식으로 한글만 추출합니다.
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')   
    result = hangul.sub('', text)
    #지우기
    return result

#새로운 ko_text라는 것은 댓글을 클리닝에다 집어넣은 것이다. 
df2['ko_text'] = df2['댓글'].apply(lambda x: text_cleaning(x))

#원래 댓글이라는 변수 칸은 지워버린다
del df2['댓글']


# 그 중에서 한 글자 이상의 텍스트를 가지고 있는 데이터만 추출합니다
df2 = df2[df2['ko_text'].str.len() > 0]
# df2.head()
# Out:
# (420, 12)

# %%
dfb = df2[df2['y'] == 1]
# dfb는 좋아요점수 입니다. 
dfc = df2[df2['y'] == 0 ]

# dfc는 나빠요 점수 입니다. 
# dfc
dfd1 = df2[df2['맛'] == 1 ]
dfd2 = df2[df2['맛'] == 2 ]
# dfc는 나빠요 점수 입니다. 
dfd= pd.concat([dfd1,dfd2])
# dfd



# 실패한 사람들이 시킨 메뉴
#정열하기 메뉴별로
dfd1 = dfd['나누기1']
dfd1 = dfd1.value_counts()
dfd1 = pd.DataFrame(dfd1)
dfd1
# Out:
#                                       나누기1
# 마후라반반치킨/1(치킨 종류 추가 선택(변경 안함))         2
# 컬투치킨/1(치킨 종류 추가 선택(변경 안함)             1
# 마후라양념치킨/1(치킨 종류 추가 선택(변경 안함))         1
# 세트1（치킨 반＋탕수육 반）/1(치킨 종류 추가 선택(변경 안함)  1
# 마후라치킨/1(치킨 종류 추가 선택(변경 안함))           1
# 감자바사삭치킨＋페스츄리핫도그/1(맛 선택(매콤（매후라）)       1
# 간장마요치킨/1(치킨 종류 추가 선택(변경 안함))          1
# 매후라치킨/1(치킨 종류 추가 선택(변경 안함))           1
# 안녕핫새우＋페스츄리핫도그/1(부위변경(순살변경)            1
# 매후라치킨/1(치킨 종류 추가 선택(변경 안함)            1
# 컬투치킨/1(치킨 종류 추가 선택(변경 안함))            1

# %%
#실패한 사람들이 시킨 메뉴
import matplotlib.pyplot as plt
dfd1 = dfd1.sort_values(by=['나누기1'], ascending=True)
dfd1=dfd1[-20:]
y= dfd1['나누기1']
x= dfd1.index
plt.figure(figsize=(3,4))
plt.rc('font', size=13)        # 기본 폰트 크기
plt.barh(x,y )

plt.show()

# %%
#실패한 사람들이 평가한 문장
a= pd.DataFrame(dfc['ko_text'])
print('부정적인 댓글 : ', len(a),"      ",round(len(dfc)/(len(dfc)+len(dfb)),4)*100, "% ")
print('긍정적인 댓글 : ', len(dfb),"     ",round(len(dfb)/(len(dfc)+len(dfb)),4)*100, "% ")

print()
print("=========================부정적인 댓글 내용 보기 ======================")
a = a.reset_index(drop= True)
a
# Out:
# 부정적인 댓글 :  21        5.050000000000001 %
# 긍정적인 댓글 :  395       94.95 %
#
# =========================부정적인 댓글 내용 보기 ======================
#                                                                                                                                                                                                                                                                    ko_text
# 0   간장마요를 시켰는데 간장양념이 몇방울 밖에 안들어갔는지 후라이드에 마요네즈 뿌려놓은것과 다를바 없었습니다 예전에 다른곳에서 먹었을때 너무 인상깊었어서 다시 시켜보았는데 아주 실망스럽습니다 화가 날 정도에요 짜증나네요 결국 조각 먹고 다 버렸습니다 개선되지 않으면 다시는 시킬일 없겠습니다
# 1   일단 매콤하지도 않고 걍 후라이드가 온거같네요 배달출발했다고 톡오고 분이 넘어도 도착안하고 예상시간지나도 안와서 전화했더니 배달 세개를 같이 갖고 나가서 늦는다고 하며 죄송하다고는 안함 행사라서 어쩔수 없다함 배달 출발한지 분지나서 도착 다 식고 눅눅하고 맛도 없고 완전 짜증남
# 2   양 많고 배달은 빠른데 맛은 보통이네요 약간 덜 익은거 같기도하고
# 3   배달이 한시간 넘은건 주말저녁이라 괜찮은데차갑게 식은 치킨은
# 4   뭔가 부족한 맛 바삭하지도 않고 웨지감자 더 있는 정도
# 5   처음 먹을때는 괜찮더니 점점 별로사장님 기름 깨끗한것좀 씁시다닭 손질좀 잘 합시다튀기고 나서 기름 잘 텁시다바로바로 튀깁시다
# 6   탕수육은 첫주문인데 괜찮아요 치킨은 자주 시켜먹는데 정망 맛있습니다 서비스 감사합니다
# ...

# %%
#긍정적인 사람들이 적은 내용보기
b= pd.DataFrame(dfb['ko_text'])
print('부정적인 댓글 :  ', len(a),"      ",round(len(dfc)/(len(dfc)+len(dfb)),4)*100, "% ")
print('긍정적인 댓글 : ', len(dfb),"     ",round(len(dfb)/(len(dfc)+len(dfb)),4)*100, "% ")

print()
print("=========================긍정적인 댓글 내용 보기 ======================")
b.head(20)
# Out:
# 부정적인 댓글 :   21        5.050000000000001 %
# 긍정적인 댓글 :  395       94.95 %
#
# =========================긍정적인 댓글 내용 보기 ======================
#                                                                                                                             ko_text
# 0   맛있었어요 또 주문할게요
# 1   맛있엉ㅅㄹ
# 2   스트레스 풀려고 주문했어요화끈하고 넘 맛있네요 치즈볼도 달콤쫀득새우튀김 맛도좋구요
# 3   치킨이 따뜻하다못해 뜨거웠네요 아주 맛있게  잘먹었습니다
# 4   맛있게 잘 먹었습니다 리뷰이벤트 감튀는 좀 더 좋은거 쓰셔도 좋을 것 같아요
# 5   행사라 싸게먹었네여
# 6   컬투치킨 처음 먹어보는데 맛있네용다음에 또 시켜먹을게요
# 7   양도 적당하고 맛있었어요
# 8   맛있습니다 추천해요
# 9   순살인데 뼈가 하나 있네요 ㅠ
# 10  넘맛있어요오오오오오 또 주문해야징 사장님 번창하세용
# 11  행사중이라서 그런지 한시간쯤 걸렸고 미리 고지받아서 괜찮았어요 양념도 맛있었고 치킨도 맛있었어요 다만 지난번엔 새우도 크고 많이 들어있었는데 오늘은 작은걸로 서너개 들어있어서 이 부분이 조금 아쉬웠어요  그래도 맛있게 먹었습니다
# 12  처음 먹어보는데새콤달콤한 옛날 치킨 맛이라 너무 좋았어요맛있게 잘 먹었습니다
# 13  매주 먹는데 이번에 특히 더 맛있네요
# 14  매주 먹는데 너무 맛있어요
# 15  저는 치킨은 무조건 이 집에서만 시켜먹어요
# 16  컬투치킨 처음 시켜봤는데 맛 괜찮네요
# 17  잘먹었습니다
# 18  윙봉먹고싶엇는데 품절되서 아쉽네여
# 19  양념 맛 최고입니다

# %%
# 양이 많기때문에 보이지 않음 그래서 특정 형태소가 어떤 형태가 있는지 확인해 보고자함

# %%
# !pip3 install konlpy
# import nltk
# nltk.download('punkt')

# %%
from konlpy.tag import *        #pip install konlpy 먼저 하세요
from matplotlib import font_manager , rc
from wordcloud import WordCloud  # pip install wordcloud 먼저 하세요
from collections import Counter
from konlpy.tag import Okt

# twit = Twitter()
twit = Okt()

dfc['token_review'] = dfc['ko_text'].apply(twit.morphs) #tokenize
dfc['tagging'] = dfc['ko_text'].apply(twit.pos) #tokenize + 형태소
dfc['Noun'] = dfc['ko_text'].apply(twit.nouns) # only 명사
# dfc[:1]

# %%
from collections import Counter
import matplotlib 
import nltk
from nltk import Text
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import numpy as np

matplotlib.rcParams['axes.unicode_minus'] = False   
#그래프에서 마이너스 기호가 표시되도록 하는 설정입니다. 

def showGraph(wordInfo):    
    
    plt.rc('font', family='NanumBarunGothic') 
    plt.figure(figsize=(16,3))
    plt.xlabel('부정적인 형태소 주요 단어')
    plt.ylabel('빈도수')
    plt.grid(True)    
    Sorted_Dict_Values = sorted(wordInfo.values(), reverse=True)
    Sorted_Dict_Keys = sorted(wordInfo, key=wordInfo.get, reverse=True)

    plt.bar(range(len(wordInfo)), Sorted_Dict_Values, align='center')
    plt.xticks(range(len(wordInfo)), Sorted_Dict_Keys, rotation='70')
    plt.show()

noun_text = [ take2 for take1 in dfc['token_review'] for take2 in take1]
text = nltk.Text(noun_text, name='NMSC')
count = Counter(text.vocab())
wordInfo = dict()
kkk = pd.DataFrame(columns=['주요내용','갯수'])

for tags, counts in text.vocab().most_common(80):
    if (len(str(tags)) > 1):
        wordInfo[tags] = counts       
        kkk=kkk.append({'주요내용':tags,'갯수':counts}, ignore_index=True)

showGraph(wordInfo)

# %%
from nltk import Text
from konlpy.tag import *        #pip install konlpy 먼저 하세요
import matplotlib.pyplot as plt #pip install matplotlib 먼저 하세요
from matplotlib import font_manager , rc
from wordcloud import WordCloud  # pip install wordcloud 먼저 하세요
from collections import Counter
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')
ok_twitter = Okt()
text = ''
for sentence in dfc['ko_text']:
  for noun in ok_twitter.nouns(sentence):
    text += noun+' '
    
content_list = text   

okt = Okt()
kkma = Kkma( )

import nltk
from nltk.probability import FreqDist

myList = okt.pos(content_list, norm=True, stem=True) # 모든 형태소 추출
# content_list 에서 형태소추출함

myList_filter = [x for x, y in myList if y in ['Noun']] # 추출된 값 중 명사만 추출

Okt = Text(myList_filter, name="Okt")
word = myList_filter

# stop1 = open('/content/drive/MyDrive/open/bul.txt',encoding='utf-8').read()

# stop_list = stop1.split(open('/content/drive/MyDrive/open/bul.txt',encoding='utf-8').read())
tok =nltk.word_tokenize(str(word))

def stopword(word_tokenize):
    result = []    
    # for w in word_tokenize:
    #     if w not in stop_list:
    #         result.append(w)            
    # return result
    for w in word_tokenize:
        result.append(w)
            
    return result

print("="*40)
print("그래프 구축 중입니다....")
print("="*40)

#okt.pos(data1)
# 그래프에서 한글이 출력이 안되는 문제 해결 (ㅁㅁㅁ 처럼 출력됨)
plt.rc('font', family='NanumBarunGothic')  
# 그래프에서 x, y 값을 설정

wordInfo = dict()

for tags, counts in Okt.vocab().most_common(30): # 출력 갯수 제한    
    if(len(str(tags)) > 0):
        wordInfo[tags] = counts # wordinfo 카운터 세기
 
    values = sorted(wordInfo.values(), reverse=True)
    keys = sorted(wordInfo, key=wordInfo.get, reverse=True)

# 그래프 값 설정 및 bar 그래프 출력
print("Bar 그래프 구축이 완료되었습니다.")
time.sleep(1)
plt.figure(figsize=(15,3))
plt.bar(range(len(wordInfo)), values, align='center')
# 그래프 x, y 라벨 설정
plt.xlabel("명사")
plt.ylabel("빈도수")
plt.xticks(range(len(wordInfo)), keys, rotation='70')
plt.show()

print("="*40)
print("WordCloud 구축중입니다....")
print("="*40)

print("WordCloud 구축이 완료되었습니다.")
font_location='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# WordCloud 출력
plt.figure(figsize=(8,4))
wc = WordCloud(width = 1000, height = 500, background_color="black", font_path=font_location, max_words=50)
plt.imshow(wc.generate_from_frequencies(Okt.vocab()))
plt.axis(False) # 네모칸을 삭제 하려면 False
plt.show()
kkk
# Out:
# ...
# 그래프 구축 중입니다....
# ...
# Bar 그래프 구축이 완료되었습니다.
# ...
# WordCloud 구축중입니다....
# ...
# WordCloud 구축이 완료되었습니다.
#      주요내용  갯수
# 0   배달     13
# 1   시간     8
# 2   주문     5
# 3   으로     5
# 4   너무     4
# 5   탕수육    4
# 6   건가     4
# 7   시킬     3
# 8   차갑게    3
# 9   치킨     3
# 10  이런     3
# 11  눅눅해서   3
# 12  소스     3
# 13  후라이드   2
# 14  다시     2
# 15  시켜     2
# 16  정도     2
# 17  하지도    2
# 18  않고     2
# 19  출발     2
# 20  오고     2
# 21  도착     2
# 22  하고     2
# 23  나서     2
# 24  저녁     2
# 25  별로     2
# 26  기름     2
# 27  자주     2
# 28  같습니다   2
# 29  ㅠㅠ     2
# 30  받고     2
# 31  이라서    2
# 32  할인     2
# 33  했는데    2
# 34  먹었습니다  2
# 35  먹어     2
# 36  같아서    2
# 37  리뷰     2
# 38  생각     2
# 39  먹었어요   2
# 40  늦게     2
# 41  보다     2
# 42  원래     2
# 43  장마     1
# 44  시켰는데   1
# 45  간장     1
# 46  양념     1
# 47  방울     1
# 48  밖에     1

# %%
# 긍정적인 댓글의 형태소를 한번 출력해봄

# %%
######긍정과 관련된 단어모음
dfb['token_review'] = dfb['ko_text'].apply(twit.morphs) #tokenize
dfb['tagging'] = dfb['ko_text'].apply(twit.pos) #tokenize + 형태소
dfb['Noun'] = dfb['ko_text'].apply(twit.nouns) # only 명사

# %%
from collections import Counter
from konlpy.tag import Okt

import matplotlib
from matplotlib import font_manager, rc

matplotlib.rcParams['axes.unicode_minus'] = False   
#그래프에서 마이너스 기호가 표시되도록 하는 설정입니다. 

def showGraph(wordInfo):
    
    font_location = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
    font_name = font_manager.FontProperties(fname=font_location).get_name()
    rc('font', family=font_name)
    plt.figure(figsize=(14,4))

    plt.xlabel('부정적인 형태소 주요 단어')
    plt.ylabel('빈도수')
    plt.grid(True)
    
    Sorted_Dict_Values = sorted(wordInfo.values(), reverse=True)
    Sorted_Dict_Keys = sorted(wordInfo, key=wordInfo.get, reverse=True)    
    plt.bar(range(len(wordInfo)), Sorted_Dict_Values, align='center')
    plt.xticks(range(len(wordInfo)), Sorted_Dict_Keys, rotation='70')
    plt.show()
    
#################################여기만 바뀜
noun_text = [ take2 for take1 in dfb['token_review'] for take2 in take1]
text = nltk.Text(noun_text, name='NMSC')
count = Counter(text.vocab())
wordInfo = dict()
kkk1 = pd.DataFrame(columns=['주요내용','갯수'])
#######################################보고자하는 갯수
for tags, counts in text.vocab().most_common(60):
    if (len(str(tags)) > 1):
        wordInfo[tags] = counts
        kkk1=kkk1.append({'주요내용':tags,'갯수':counts}, ignore_index=True)
showGraph(wordInfo)

# %%
from nltk import Text

from nltk import Text
from konlpy.tag import *        #pip install konlpy 먼저 하세요
import matplotlib.pyplot as plt #pip install matplotlib 먼저 하세요
from matplotlib import font_manager , rc
from wordcloud import WordCloud  # pip install wordcloud 먼저 하세요
from collections import Counter
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')
#   reply = f.readlines()


# # 크롤링한 댓글파일 가져와서 리스트 변수에 저장
# # 반드시 문자 사이 공백을 넣어야지 wordcloud에서 분석 가능!!
ok_twitter = Okt()
text = ''
for sentence in dfb['ko_text']:
    for noun in ok_twitter.nouns(sentence):
        text += noun+' '

  
    
content_list = text   


okt = Okt()
kkma = Kkma( )

import nltk
from nltk.probability import FreqDist


myList = okt.pos(content_list, norm=True, stem=True) # 모든 형태소 추출
# content_list 에서 형태소추출함

myList_filter = [x for x, y in myList if y in ['Noun']] # 추출된 값 중 명사만 추출
  
    
Okt = Text(myList_filter, name="Okt")

word = myList_filter

# stop1 = open('c:/123kms1/불용어모음.txt',encoding='utf-8').read()

# stop_list = stop1.split(open('c:/123kms1/불용어모음.txt',encoding='utf-8').read())
tok =nltk.word_tokenize(str(word))

def stopword(word_tokenize):
    result = []
    for w in word_tokenize:
        # if w not in stop_list:
        result.append(w)
            
    return result


# 그래프에서 한글이 출력이 안되는 문제 해결 (ㅁㅁㅁ 처럼 출력됨)

font_location = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

font_name = font_manager.FontProperties(fname=font_location).get_name()

rc('font', family=font_name)
 
# 그래프에서 x, y 값을 설정

wordInfo = dict()
#########################################출력갯수 제한
for tags, counts in Okt.vocab().most_common(30): # 출력 갯수 제한
    
    if(len(str(tags)) > 0):
        wordInfo[tags] = counts # wordinfo 카운터 세기
 
    values = sorted(wordInfo.values(), reverse=True)
    keys = sorted(wordInfo, key=wordInfo.get, reverse=True)

# 그래프 값 설정 및 bar 그래프 출력
print("Bar 그래프 구축이 완료되었습니다.")
time.sleep(1)
plt.figure(figsize=(12,8))
plt.bar(range(len(wordInfo)), values, align='center')
# 그래프 x, y 라벨 설정
plt.xlabel("명사")
plt.ylabel("빈도수")
plt.xticks(range(len(wordInfo)), keys, rotation='90')
plt.show()


print("="*40)
print("WordCloud 구축중입니다....")
print("="*40)
# WordCloud 출력
plt.figure(figsize=(12,8))
wc = WordCloud(width = 1000, height = 500, background_color="white", font_path=font_location, max_words=250)
plt.imshow(wc.generate_from_frequencies(Okt.vocab()))
plt.axis(False) # 네모칸을 삭제 하려면 False
plt.show()
# wc.to_file('c:/123kms/긍정어wc_result.png')
# print('저장도 완료했습니다. ')
# Out:
# Bar 그래프 구축이 완료되었습니다.
# ...
# WordCloud 구축중입니다....
# ...

# %%
kkk1
# Out:
#      주요내용  갯수
# 0   치킨     94
# 1   먹었습니다  88
# 2   맛있게    73
# 3   맛있어요   66
# 4   배달     64
# 5   너무     51
# 6   시켜     29
# 7   양념     28
# 8   맛있네요   26
# 9   컬투     25
# 10  최고     23
# 11  항상     23
# 12  주문     22
# 13  처음     22
# 14  정말     21
# 15  양도     20
# 16  맛있습니다  20
# 17  먹었어요   20
# 18  감사합니다  20
# 19  소스     20
# 20  하고     18
# 21  ㅎㅎ     18
# 22  맛있었어요  17
# 23  시간     17
# 24  다음     16
# 25  빠르고    16
# 26  먹어     15
# 27  합니다    15
# 28  튀김     14
# 29  입니다    14
# 30  감자     14
# 31  않고     14
# 32  좋아요    14
# 33  바삭     14
# 34  많고     14
# 35  후라이드   13
# 36  진짜     13
# 37  봤는데    12
# 38  엄청     12
# 39  보다     12
